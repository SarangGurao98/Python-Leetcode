# %%
"""
Runtime 196 ms Beats 7.57%  Memory 18.1 MB Beats 18.93%
Runtime 216 ms Beats 5.29%  Memory 17.9 MB Beats 93.75% 


26. Remove Duplicates from Sorted Array - Easy - Companies

Given an integer array nums sorted in non-decreasing order, remove the duplicates in-place such that 
each unique element appears only once. The relative order of the elements should be kept the same. 
Then return the number of unique elements in nums.
Consider the number of unique elements of nums to be k, to get accepted, you need to do the following things:
Change the array nums such that the first k elements of nums contain the unique elements in the order 
they were present in nums initially. The remaining elements of nums are not important as well as the size of nums.
Return k.
Custom Judge:

The judge will test your solution with the following code:
int[] nums = [...]; // Input array
int[] expectedNums = [...]; // The expected answer with correct length

int k = removeDuplicates(nums); // Calls your implementation

assert k == expectedNums.length;
for (int i = 0; i < k; i++) {
    assert nums[i] == expectedNums[i];
}
If all assertions pass, then your solution will be accepted.

 

Example 1:

Input: nums = [1,1,2]
Output: 2, nums = [1,2,_]
Explanation: Your function should return k = 2, with the first two elements of nums being 1 and 2 respectively.
It does not matter what you leave beyond the returned k (hence they are underscores).
Example 2:

Input: nums = [0,0,1,1,1,2,2,3,3,4]
Output: 5, nums = [0,1,2,3,4,_,_,_,_,_]
Explanation: Your function should return k = 5, with the first five elements of nums being 0, 1, 2, 3, and 4 respectively.
It does not matter what you leave beyond the returned k (hence they are underscores).
 

Constraints:

1 <= nums.length <= 3 * 104
-100 <= nums[i] <= 100
nums is sorted in non-decreasing order.


        k=len(nums)    
        i=0
        previous = None
        while i<k:
            if previous != nums[i]:
                previous = nums[i]
            else:
                nums.remove(nums[i])
                k-=1
                i-=1
            i+=1
        
        k=len(nums)  


"""
nums = [1,1,2]  # Output: 2, nums = [1,2,_]
nums = [0,0,1,1,1,2,2,3,3,4] # Output: 5, nums = [0,1,2,3,4,_,_,_,_,_]
nums = [1]
nums = [-1,0,0,0,0,3,3] # Output = [-1,0,3]
print(f"Input nums : {nums}")


"""delnums1 = list(set(nums))
delnums1.sort()
print(f"Input nums1 :{delnums1}")
outputNum = len(delnums1)
i=0
j=0
while i<outputNum and outputNum!=len(nums) :
    while delnums1[i] == nums[j]:
        j+=1
        if delnums1[i] == nums[j]:
            nums.pop(j)
            nums.append('_')
            j-=1
    i+=1
"""
i=0
j=1
k = len(nums)
while i<len(nums) and j<len(nums):
    #print(f"nums :{nums}")
    #print(f"i:{i}, j:{j}")
    if nums[i]!='_':
        while nums[i] == nums[j]:
            #print(f"------------------------")
            if nums[i] == nums[j]:
                nums.pop(j)
                nums.append('_')
                k-=1
                j-=1
                i-=1
    else:
        break
    i+=1
    j+=1
print(f"Input nums :{nums}")
print(f"Input nums :{k}")
# Out:
# Input nums : [-1, 0, 0, 0, 0, 3, 3]
# Input nums :[-1, 0, 3, '_', '_', '_', '_']
# Input nums :3
