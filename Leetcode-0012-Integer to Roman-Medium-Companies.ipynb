# %%
"""
Leetcode-0012-Integer to Roman-Medium-Companies

Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.

Symbol       Value
I             1
V             5
X             10
L             50
C             100
D             500
M             1000
For example, 2 is written as II in Roman numeral, just two one's added together. 12 is written as XII, 
which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.

Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. 
Instead, the number four is written as IV. Because the one is before the five we subtract it making four. 
The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:
I can be placed before V (5) and X (10) to make 4 and 9. 
X can be placed before L (50) and C (100) to make 40 and 90. 
C can be placed before D (500) and M (1000) to make 400 and 900.
Given an integer, convert it to a roman numeral.

Example 1:
Input: num = 3
Output: "III"
Explanation: 3 is represented as 3 ones.

Example 2:
Input: num = 58
Output: "LVIII"
Explanation: L = 50, V = 5, III = 3.

Example 3:
Input: num = 1994
Output: "MCMXCIV"
Explanation: M = 1000, CM = 900, XC = 90 and IV = 4.

Constraints:
1 <= num <= 3999
"""

# %%
#num = 3 
#Output: "III" Explanation: 3 is represented as 3 ones.
#num = 58
#Output: "LVIII" Explanation: L = 50, V = 5, III = 3.
num = 1994
#Output: "MCMXCIV" Explanation: M = 1000, CM = 900, XC = 90 and IV = 4.


num =2

romArr = ['I','V','X','L','C','D',   'M']
intArr = [1,   5, 10, 50, 100,500,  1000]
#romArr = ['M',  'D', 'C','L','X','V','I']
#intArr = [1000, 500, 100, 50, 10, 5,  1 ]
print(f"Input Integer Number: {num}")
outputRoman = ""

#89 = LXXXIX
#45 = XLV


s = str(num)
j=1

for i in range(len(s)-1, -1,-1):
    k=0
    x = int(s[i])*j
    print(f"------------------------------------------------------")
    print(f"Current integer : {x}")
    temp = ""
    inttemp = 0
    while intArr[k]<x:
        k+=1
    while x!=inttemp:
        print(f"Current k : {k}")
        #if intArr[k-1]*3>=x:
        #    k=k-1
        print(f"New Current k : {k}")
        temp = romArr[k]
        inttemp = intArr[k]
        while x!=inttemp:
            if x<inttemp:
                temp = romArr[k-1]+temp
                inttemp-=intArr[k-1]
            if x>inttemp:
                temp = temp+romArr[k]
                inttemp+=intArr[k]
        print(f"Current temp : {temp}")
    inttemp=0
    outputRoman+=temp
    j=j*10

print(f"Output Integer Number: {outputRoman}")
# Out:
# Input Integer Number: 2
# ------------------------------------------------------
# Current integer : 2
# Current k : 1
# New Current k : 1
# Current temp : IIIV
# Output Integer Number: IIIV

# %%
1994%1000

# %%
def romanToInt(self, s: str) -> int:
        romArr = ['I','V','X','L','C','D',   'M']
        intArr = [1,   5, 10, 50, 100,500,  1000]

        #print(f"Input Roman Number: {s}")
        outputInt = 0
        for i in range(len(s)-1, -1,-1):
            temp = intArr[romArr.index(s[i])]
            if i==len(s)-1:
                outputInt+= temp
            elif romArr.index(s[i])<romArr.index(s[i+1]):
                outputInt-= temp
            else:
                outputInt+= temp
                
        #print(f"Output Integer Number: {outputInt}")
        return outputInt
